# %%
import pandas as pd
import numpy as np

# %% [markdown]
# https://ru.onlinemschool.com/math/assistance/matrix/multiply/?oms_all=a%3d%7b%7b2,4%7d,%7b6,5%7d%7d,b%3d%7b%7b2,3%7d,%7b4,5%7d%7d
#
#
# https://ru.wikibooks.org/wiki/%D0%9C%D0%B0%D1%82%D0%B5%D0%BC%D0%B0%D1%82%D0%B8%D1%87%D0%B5%D1%81%D0%BA%D0%B8%D0%B5_%D1%84%D0%BE%D1%80%D0%BC%D1%83%D0%BB%D1%8B_%D0%B2_LaTeX
#
# https://developers.google.com/machine-learning/crash-course/california-housing-data-description?hl=ru

# %% [markdown]
# Визуализация данных:
#
# https://seaborn.pydata.org/examples/index.html
#
# https://plotly.com/python/
#
# https://matplotlib.org/stable/gallery/index.html

# %% [markdown]
# **Работа с Numpy**
#
# Калькулятор: https://ru.onlinemschool.com/math/assistance/matrix/multiply/

# %%
A = np.array([[2, 4], 
              [6, 5]])
B = np.array([[2, 3], 
              [4, 5]])

# %%
A
# Out:
# array([[2, 4],
#        [6, 5]])

# %%
B
# Out:
# array([[2, 3],
#        [4, 5]])

# %%
A @ B
# Out:
# array([[20, 26],
#        [32, 43]])

# %% [markdown]
# # Работа с данными

# %%
# Загрузка данных
df = pd.read_csv("sample_data/california_housing_test.csv")
df.head(10)
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2    -117.81     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
# 5    -119.56     36.51                37.0       1018.0           213.0
# 6    -121.43     38.63                43.0       1009.0           225.0
# 7    -120.65     35.48                19.0       2310.0           471.0
# 8    -122.84     38.40                15.0       3080.0           617.0
# 9    -118.02     34.08                31.0       2402.0           632.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# ...

# %% [markdown]
# # Горячие клавишы:
#
# **ESC + A - Создать новую строку сверху**
#
# **ESC + B - Создать новую строку снизу**
#
# **Использование формул:**
#
# # $$k_{n+1} = n^2 + k_n^2 - k_{n-1}$$

# %%
# Размерность DataFrame
df.shape
# Out:
# (3000, 9)

# %%
# Информация про DataFrame
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3000 entries, 0 to 2999
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           3000 non-null   float64
#  1   latitude            3000 non-null   float64
#  2   housing_median_age  3000 non-null   float64
#  3   total_rooms         3000 non-null   float64
#  4   total_bedrooms      3000 non-null   float64
#  5   population          3000 non-null   float64
#  6   households          3000 non-null   float64
#  7   median_income       3000 non-null   float64
#  8   median_house_value  3000 non-null   float64
# dtypes: float64(9)
# memory usage: 211.1 KB

# %%
# Количество пустых значений
df.isnull().sum()
# Out:
# longitude             1
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
# Добавим пустое значение
df['longitude'][2] = np.nan

# %%
df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2           NaN     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# ### Посчитаем количество пустых значений

# %%
df.isnull()
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0         False     False               False        False           False
# 1         False     False               False        False           False
# 2          True     False               False        False           False
# 3         False     False               False        False           False
# 4         False     False               False        False           False
# ...         ...       ...                 ...          ...             ...
# 2995      False     False               False        False           False
# 2996      False     False               False        False           False
# 2997      False     False               False        False           False
# 2998      False     False               False        False           False
# 2999      False     False               False        False           False
#
#       population  households  median_income  median_house_value
# ...

# %%
# Мы можем True складывать, это равносильно 1
True + 10
# Out:
# 11

# %%
# Просуммируем все True и False, которые вернул isnull()
df.isnull().sum()
# Out:
# longitude             1
# latitude              0
# housing_median_age    0
# total_rooms           0
# total_bedrooms        0
# population            0
# households            0
# median_income         0
# median_house_value    0
# dtype: int64

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2        NaN     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# # Среднее / Медиана / Мода

# %%
df["housing_median_age"].mean()
# Out:
# 28.845333333333333

# %%
[1, 20, -10, 20, 20, 300]

# %%
np.mean([1, 20, -10, 20, 20, 300])
# Out:
# 58.5

# %%
np.median([1, 20, -10, 20, 20, 300])
# Out:
# 20.0

# %%
sorted([1, 20, -10, 20, 20, 300])
# Out:
# [-10, 1, 20, 20, 20, 300]

# %%
df["housing_median_age"].median()
# Out:
# 29.0

# %%
df["housing_median_age"].mode()
# Out:
# 0    52.0
# Name: housing_median_age, dtype: float64

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2        NaN     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %%
new_df = df[df["housing_median_age"] >= 40]
new_df
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 1       -118.30     34.26                43.0       1510.0           310.0
# 6       -121.43     38.63                43.0       1009.0           225.0
# 10      -118.24     33.98                45.0        972.0           249.0
# 15      -117.99     33.81                42.0        161.0            40.0
# 20      -122.15     37.75                40.0       1445.0           256.0
# ...         ...       ...                 ...          ...             ...
# 2988    -122.01     36.97                43.0       2162.0           509.0
# 2990    -118.23     34.09                49.0       1638.0           456.0
# 2992    -122.33     37.39                52.0        573.0           102.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
new_df["housing_median_age"].max()
# Out:
# 52.0

# %% [markdown]
# Выбрать данные где housing_median_age < 20 и
# median_house_value > 70000

# %%
df.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.05     37.37                27.0       3885.0           661.0
# 1    -118.30     34.26                43.0       1510.0           310.0
# 2        NaN     33.78                27.0       3589.0           507.0
# 3    -118.36     33.82                28.0         67.0            15.0
# 4    -119.67     36.33                19.0       1241.0           244.0
#
#    population  households  median_income  median_house_value
# 0      1537.0       606.0         6.6085            344700.0
# 1       809.0       277.0         3.5990            176500.0
# 2      1484.0       495.0         5.7934            270500.0
# 3        49.0        11.0         6.1359            330000.0
# 4       850.0       237.0         2.9375             81700.0

# %% [markdown]
# # То, как работают условия - True, True, ... , False

# %%
df["housing_median_age"] == 27.0
# Out:
# 0        True
# 1       False
# 2        True
# 3       False
# 4       False
#         ...
# 2995    False
# 2996     True
# 2997    False
# 2998    False
# 2999    False
# Name: housing_median_age, Length: 3000, dtype: bool

# %%
df[[True for i in range(3000)]]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 1       -118.30     34.26                43.0       1510.0           310.0
# 2           NaN     33.78                27.0       3589.0           507.0
# 3       -118.36     33.82                28.0         67.0            15.0
# 4       -119.67     36.33                19.0       1241.0           244.0
# ...         ...       ...                 ...          ...             ...
# 2995    -119.86     34.42                23.0       1450.0           642.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
# 2997    -119.70     36.30                10.0        956.0           201.0
# 2998    -117.12     34.10                40.0         96.0            14.0
# 2999    -119.63     34.42                42.0       1765.0           263.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[df["housing_median_age"] == 27.0]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0       -122.05     37.37                27.0       3885.0           661.0
# 2           NaN     33.78                27.0       3589.0           507.0
# 14      -117.97     33.73                27.0       2097.0           325.0
# 112     -117.95     33.63                27.0       2489.0           481.0
# 255     -118.86     34.19                27.0       1931.0           261.0
# ...         ...       ...                 ...          ...             ...
# 2855    -118.70     34.28                27.0       3536.0           646.0
# 2881    -124.14     40.60                27.0       1148.0           206.0
# 2909    -122.11     37.41                27.0       5110.0          1599.0
# 2957    -118.23     33.91                27.0       1694.0           393.0
# 2996    -118.14     34.06                27.0       5257.0          1082.0
#
#       population  households  median_income  median_house_value
# ...

# %%
df[(df["housing_median_age"] < 20) & (df["median_house_value"] > 70000)]
# Out:
#       longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 4       -119.67     36.33                19.0       1241.0           244.0
# 7       -120.65     35.48                19.0       2310.0           471.0
# 8       -122.84     38.40                15.0       3080.0           617.0
# 13      -117.03     32.97                16.0       3936.0           694.0
# 16      -120.81     37.53                15.0        570.0           123.0
# ...         ...       ...                 ...          ...             ...
# 2978    -121.34     38.64                17.0       2761.0           501.0
# 2981    -120.66     35.49                17.0       4422.0           945.0
# 2984    -117.59     33.88                13.0       3239.0           849.0
# 2985    -120.47     34.94                17.0       1368.0           308.0
# 2991    -117.17     34.28                13.0       4867.0           718.0
#
#       population  households  median_income  median_house_value
# ...

# %% [markdown]
# ## Статистика по данным

# %%
df.describe()
# Out:
#          longitude    latitude  housing_median_age   total_rooms  \
# count  2999.000000  3000.00000         3000.000000   3000.000000
# mean   -119.589793    35.63539           28.845333   2599.578667
# std       1.995004     2.12967           12.555396   2155.593332
# min    -124.180000    32.56000            1.000000      6.000000
# 25%    -121.810000    33.93000           18.000000   1401.000000
# 50%    -118.490000    34.27000           29.000000   2106.000000
# 75%    -118.020000    37.69000           37.000000   3129.000000
# max    -114.490000    41.92000           52.000000  30450.000000
#
#        total_bedrooms    population  households  median_income  \
# count     3000.000000   3000.000000  3000.00000    3000.000000
# mean       529.950667   1402.798667   489.91200       3.807272
# std        415.654368   1030.543012   365.42271       1.854512
# min          2.000000      5.000000     2.00000       0.499900
# ...

# %% [markdown]
# ## Пример визуализации из matplotlib

# %%
import matplotlib.pyplot as plt

fig, ax = plt.subplots()

fruits = ['apple', 'blueberry', 'cherry', 'orange']
counts = [40, 100, 30, 55]
bar_labels = ['red', 'blue', '_red', 'orange']
bar_colors = ['tab:red', 'tab:blue', 'tab:red', 'tab:orange']

ax.bar(fruits, counts, label=bar_labels, color=bar_colors)

ax.set_ylabel('fruit supply')
ax.set_title('Fruit supply by kind and color')
ax.legend(title='Fruit color')

plt.show()
